# %% [markdown]
# ## DBC - Commodities

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import numpy as np
import seaborn as sns
import os

# %%
ticker = 'XHB'

# %%
start='2007-01-01'
end='2019-08-21'

# %%
financial_data = web.DataReader(ticker, 'yahoo', start, end)

# %% [markdown]
# ## Vizualizating

# %%
for col in financial_data.columns[:5]:
    plt.figure(figsize=(18,2))
    plt.title(col)
    financial_data[col].plot()

# %% [markdown]
# ## Rolling Mean

# %%
exp_rolmean = financial_data['Close'].ewm(halflife = 2).mean()
data_minus_exp_rolmean = financial_data['Close'] - exp_rolmean


fig = plt.figure(figsize=(16,3))
plt.plot(data_minus_exp_rolmean, color='blue',label='Sales - rolling mean')
plt.legend(loc='best')
plt.title('Price while the rolling mean is subtracted')
plt.show(block=False)

# %% [markdown]
# ## Differentiating

# %%
data_diff = financial_data['Close'].diff(periods=1)
data_diff.head(10)

fig = plt.figure(figsize=(16,3))
plt.plot(data_diff, color='blue',label='Price - rolling mean')
plt.legend(loc='best')
plt.title('Differenced Price Series')
plt.show(block=False)

# %% [markdown]
# ## RSI - Relative Strength Index

# %%
def RSI(df,col):
    
    values=df[col]

    RSI=[0]*14


    up, down = [],[]

    for i in range(0,14):
        if values[i+1]> values[i]:
            high=values[i+1]-values[i]
            up.append(high)
        elif values[i+1]< values[i]:
            low=values[i]-values[i+1]
            down.append(low) 
    
    avup = sum(up)/14
    avdown= sum(down)/14+0.00000000000000001
    RS = avup/avdown
    rsi= 100 - (100/(1+RS))
    
    RSI.append(rsi)

    for row in range(15,len(values)):
        if values[row]>values[row-1]:
            high=values[row]-values[row-1]
            avup=(avup*13+high)/14
            avdown=avdown*13/14
            RS = avup/avdown
            rsi= 100 - (100/(1+RS))
            RSI.append(rsi)
            
        else:
            low=values[row-1]-values[row]
            avup=(avup*13)/14
            avdown=(avdown*13+low)/14
            RS = avup/avdown
            rsi= 100 - (100/(1+RS))
            RSI.append(rsi)
        
    df['RSI']=RSI

# %%
RSI(financial_data,'Close')
financial_data = financial_data[financial_data.RSI!=0]

# %%
fig = plt.figure(figsize=(16,3))
plt.plot(financial_data['RSI'], color='blue',label='RSI')
plt.legend(loc='best')
plt.axhline(y=30, color='g', linestyle='-')
plt.axhline(y=70, color='r', linestyle='-')
plt.title('RSI')
plt.show(block=False)

# %% [markdown]
# ## The Dickey Fuller Test

# %%
dftest = adfuller(financial_data['Close'])

# Extract and display test results in a user friendly manner
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
#print(dftest)
print ('Results of Dickey-Fuller Test:')
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.097223
# p-value                           0.716178
# #Lags Used                        0.000000
# Number of Observations Used    3167.000000
# Critical Value (1%)              -3.432417
# Critical Value (5%)              -2.862453
# Critical Value (10%)             -2.567256
# dtype: float64

# %% [markdown]
# ## Features Correlations

# %%
corr = financial_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col0 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col1 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col2 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col3 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col4 {
#             background-color:  #3d50c3;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col5 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col6 {
#             background-color:  #799cf8;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col0 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col1 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col2 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col3 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col4 {
#             background-color:  #3b4cc0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col5 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col6 {
#             background-color:  #7b9ff9;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col0 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col1 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col2 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col3 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col4 {
#             background-color:  #3c4ec2;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col5 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col6 {
#             background-color:  #779af7;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row3_col0 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row3_col1 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row3_col2 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row3_col3 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row3_col4 {
#             background-color:  #3c4ec2;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row3_col5 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row3_col6 {
#             background-color:  #7b9ff9;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row4_col0 {
#             background-color:  #3b4cc0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row4_col1 {
#             background-color:  #3b4cc0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row4_col4 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row4_col6 {
#             background-color:  #3b4cc0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row5_col0 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row5_col1 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row5_col2 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row5_col3 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row5_col4 {
#             background-color:  #3c4ec2;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row5_col5 {
#             background-color:  #b40426;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row5_col6 {
#             background-color:  #7ea1fa;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row6_col0 {
#             background-color:  #c5d6f2;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row6_col1 {
#             background-color:  #c9d7f0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row6_col2 {
#             background-color:  #c5d6f2;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row6_col3 {
#             background-color:  #c7d7f0;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row6_col4 {
#             background-color:  #98b9ff;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row6_col5 {
#             background-color:  #cad8ef;
#         }    #T_c262ceda_d261_11e9_932f_646e6999a9b8row6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_c262ceda_d261_11e9_932f_646e6999a9b8" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >High</th>
#         <th class="col_heading level0 col1" >Low</th>
#         <th class="col_heading level0 col2" >Open</th>
#         <th class="col_heading level0 col3" >Close</th>
#         <th class="col_heading level0 col4" >Volume</th>
#         <th class="col_heading level0 col5" >Adj Close</th>
#         <th class="col_heading level0 col6" >RSI</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c262ceda_d261_11e9_932f_646e6999a9b8level0_row0" class="row_heading level0 row0" >High</th>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col0" class="data row0 col0" >1</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col1" class="data row0 col1" >0.999311</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col2" class="data row0 col2" >0.999568</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col3" class="data row0 col3" >0.999561</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col4" class="data row0 col4" >-0.510955</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col5" class="data row0 col5" >0.995941</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row0_col6" class="data row0 col6" >0.115574</td>
#     </tr>    <tr>
#         <th id="T_c262ceda_d261_11e9_932f_646e6999a9b8level0_row1" class="row_heading level0 row1" >Low</th>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col0" class="data row1 col0" >0.999311</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col1" class="data row1 col1" >1</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col2" class="data row1 col2" >0.999499</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col3" class="data row1 col3" >0.999532</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col4" class="data row1 col4" >-0.525726</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col5" class="data row1 col5" >0.996704</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row1_col6" class="data row1 col6" >0.125031</td>
#     </tr>    <tr>
#         <th id="T_c262ceda_d261_11e9_932f_646e6999a9b8level0_row2" class="row_heading level0 row2" >Open</th>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col0" class="data row2 col0" >0.999568</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col1" class="data row2 col1" >0.999499</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col2" class="data row2 col2" >1</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col3" class="data row2 col3" >0.999099</td>
#         <td id="T_c262ceda_d261_11e9_932f_646e6999a9b8row2_col4" class="data row2 col4" >-0.518446

# %%
corr = financial_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col0 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col1 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col2 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col3 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col4 {
#             background-color:  #3d50c3;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col5 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col6 {
#             background-color:  #799cf8;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col0 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col1 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col2 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col3 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col4 {
#             background-color:  #3b4cc0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col5 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col6 {
#             background-color:  #7b9ff9;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col0 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col1 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col2 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col3 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col4 {
#             background-color:  #3c4ec2;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col5 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col6 {
#             background-color:  #779af7;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row3_col0 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row3_col1 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row3_col2 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row3_col3 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row3_col4 {
#             background-color:  #3c4ec2;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row3_col5 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row3_col6 {
#             background-color:  #7b9ff9;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row4_col0 {
#             background-color:  #3b4cc0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row4_col1 {
#             background-color:  #3b4cc0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row4_col2 {
#             background-color:  #3b4cc0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row4_col4 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row4_col5 {
#             background-color:  #3b4cc0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row4_col6 {
#             background-color:  #3b4cc0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row5_col0 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row5_col1 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row5_col2 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row5_col3 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row5_col4 {
#             background-color:  #3c4ec2;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row5_col5 {
#             background-color:  #b40426;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row5_col6 {
#             background-color:  #7ea1fa;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row6_col0 {
#             background-color:  #c5d6f2;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row6_col1 {
#             background-color:  #c9d7f0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row6_col2 {
#             background-color:  #c5d6f2;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row6_col3 {
#             background-color:  #c7d7f0;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row6_col4 {
#             background-color:  #98b9ff;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row6_col5 {
#             background-color:  #cad8ef;
#         }    #T_c26ecb76_d261_11e9_a87e_646e6999a9b8row6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >High</th>
#         <th class="col_heading level0 col1" >Low</th>
#         <th class="col_heading level0 col2" >Open</th>
#         <th class="col_heading level0 col3" >Close</th>
#         <th class="col_heading level0 col4" >Volume</th>
#         <th class="col_heading level0 col5" >Adj Close</th>
#         <th class="col_heading level0 col6" >RSI</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8level0_row0" class="row_heading level0 row0" >High</th>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col0" class="data row0 col0" >1</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col1" class="data row0 col1" >0.999311</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col2" class="data row0 col2" >0.999568</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col3" class="data row0 col3" >0.999561</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col4" class="data row0 col4" >-0.510955</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col5" class="data row0 col5" >0.995941</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row0_col6" class="data row0 col6" >0.115574</td>
#     </tr>    <tr>
#         <th id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8level0_row1" class="row_heading level0 row1" >Low</th>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col0" class="data row1 col0" >0.999311</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col1" class="data row1 col1" >1</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col2" class="data row1 col2" >0.999499</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col3" class="data row1 col3" >0.999532</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col4" class="data row1 col4" >-0.525726</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col5" class="data row1 col5" >0.996704</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row1_col6" class="data row1 col6" >0.125031</td>
#     </tr>    <tr>
#         <th id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8level0_row2" class="row_heading level0 row2" >Open</th>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col0" class="data row2 col0" >0.999568</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col1" class="data row2 col1" >0.999499</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col2" class="data row2 col2" >1</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col3" class="data row2 col3" >0.999099</td>
#         <td id="T_c26ecb76_d261_11e9_a87e_646e6999a9b8row2_col4" class="data row2 col4" >-0.518446

# %%
financial_data.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close  \
# Date
# 2007-01-24  38.349998  37.500000  37.919998  38.250000   718800.0  33.516464
# 2007-01-25  38.330002  37.029999  38.279999  37.349998  2177100.0  32.727840
# 2007-01-26  37.470001  36.639999  37.200001  36.730000  2993300.0  32.184578
# 2007-01-29  37.169998  36.740002  36.740002  36.900002   462900.0  32.333542
# 2007-01-30  37.119999  36.869999  36.980000  36.900002   502500.0  32.333542
#
#                   RSI
# Date
# 2007-01-24  69.315646
# 2007-01-25  57.098870
# 2007-01-26  50.496242
# 2007-01-29  52.130774
# 2007-01-30  52.130774

# %% [markdown]
# ## Adding Suffixes

# %%
new_cols=[]
for c in list(financial_data.columns):
    updated = c+'_'+ticker
    new_cols.append(updated)
financial_data.columns=new_cols

# %%
financial_data.head()
# Out:
#              High_XHB    Low_XHB   Open_XHB  Close_XHB  Volume_XHB  \
# Date
# 2007-01-24  38.349998  37.500000  37.919998  38.250000    718800.0
# 2007-01-25  38.330002  37.029999  38.279999  37.349998   2177100.0
# 2007-01-26  37.470001  36.639999  37.200001  36.730000   2993300.0
# 2007-01-29  37.169998  36.740002  36.740002  36.900002    462900.0
# 2007-01-30  37.119999  36.869999  36.980000  36.900002    502500.0
#
#             Adj Close_XHB    RSI_XHB
# Date
# 2007-01-24      33.516464  69.315646
# 2007-01-25      32.727840  57.098870
# 2007-01-26      32.184578  50.496242
# 2007-01-29      32.333542  52.130774
# 2007-01-30      32.333542  52.130774

# %% [markdown]
# ## Saving into final data csv file

# %%
#loading combined dataframe 
final_data=pd.read_csv('final_data.csv')
final_data=final_data.set_index('Date', drop=True)

# %%
#merging
final_data=final_data.merge(financial_data, left_index=True, right_index=True)

# %%
#checking
print(len(final_data))
final_data.head()
# Out:
# 2754
#             newsSentiment  Bullish  Neutral  Bearish  Bullish 8-Week Mov Avg  \
# Date
# 2007-01-24           0.42   0.5778   0.1515   0.2727                0.446163
# 2007-01-25           0.39   0.3951   0.2716   0.3333                0.445275
# 2007-01-26          -0.31   0.3951   0.2716   0.3333                0.445275
# 2007-01-29           0.17   0.3951   0.2716   0.3333                0.445275
# 2007-01-30           0.47   0.3951   0.2716   0.3333                0.445275
#
#             Bull-Bear Spread  Bullish Average  Bullish Average + St. Dev  \
# Date
# 2007-01-24            0.3051         0.384907                   0.488293
# 2007-01-25            0.0618         0.384907                   0.488293
# 2007-01-26            0.0618         0.384907                   0.488293
# 2007-01-29            0.0618         0.384907                   0.488293
# 2007-01-30            0.0618         0.384907                   0.488293
#
#             Bullish Average - St. Dev   High_DBC    ...      Volume_USO  \
# Date                                                ...
# 2007-01-24                   0.281522  23.629999    ...         5369600
# 2007-01-25                   0.281522  23.700001    ...         3792800
# 2007-01-26                   0.281522  23.600000    ...         4386000
# 2007-01-29                   0.281522  23.450001    ...         3129600
# 2007-01-30                   0.281522  23.750000    ...         5706500
#
#             Adj Close_USO    RSI_USO   High_XHB    Low_XHB   Open_XHB  \
# Date
# 2007-01-24      46.099998  37.723212  38.349998  37.500000  37.919998
# 2007-01-25      45.270000  35.370832  38.330002  37.029999  38.279999
# 2007-01-26      46.279999  40.253317  37.470001  36.639999  37.200001
# 2007-01-29      44.970001  36.411110  37.169998  36.740002  36.740002
# 2007-01-30      47.360001  46.453209  37.119999  36.869999  36.980000
#
#             Close_XHB  Volume_XHB  Adj Close_XHB    RSI_XHB
# Date
# 2007-01-24  38.250000    718800.0      33.516464  69.315646
# 2007-01-25  37.349998   2177100.0      32.727840  57.098870
# 2007-01-26  36.730000   2993300.0      32.184578  50.496242
# 2007-01-29  36.900002    462900.0      32.333542  52.130774
# 2007-01-30  36.900002    502500.0      32.333542  52.130774
#
# [5 rows x 75 columns]

# %%
#saving
final_data.to_csv('final_data.csv')
